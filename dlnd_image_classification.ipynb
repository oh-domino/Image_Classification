# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/256


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing
lb_encoding = None

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    global lb_encoding

    if lb_encoding is not None:
        return lb_encoding.transform(x)
    else:
        lb = preprocessing.LabelBinarizer()
        lb_encoding = lb.fit(x)
        return lb_encoding.transform(x)
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, *image_shape], name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=None, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #weight = tf.Variable(tf.random_normal((conv_ksize[0], conv_ksize[1],int(x_tensor.get_shape[3]), conv_num_outputs), mean=0.0, stddev=0.1), trainable=True)
    #bias = tf.Variable(tf.zeros(conv_num_outputs))
    batch_size, x_height, x_width, x_depth = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([*conv_ksize, x_depth, conv_num_outputs],stddev=0.01))
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    
    conv_layer = tf.nn.conv2d(
        x_tensor, 
        weight, 
        strides=[1, conv_strides[0], conv_strides[1], 1], 
        padding='SAME')
    
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    # Apply Max Pooling
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=[1, pool_ksize[0], pool_ksize[1], 1],
        strides=[1, pool_strides[0], pool_strides[1], 1],
        padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    x = tf.contrib.layers.flatten(x_tensor)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn=tf.nn.relu)



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn=None)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that holds dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    
    x_tensor = x
    conv_num_outputs = 32
    conv_ksize = (3,3) 
    conv_strides = (1,1)
    pool_ksize = (3,3)
    pool_strides = (1,1)
    num_outputs = 10
    
    neural_net = conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    neural_net = conv2d_maxpool(neural_net, 2*conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #neural_net = conv2d_maxpool(neural_net, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    neural_net = flatten(neural_net)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    neural_net = fully_conn(neural_net, 1024)
    neural_net = tf.nn.dropout(neural_net, keep_prob)
    neural_net = fully_conn(neural_net, 256)
    neural_net = tf.nn.dropout(neural_net, keep_prob)
    neural_net = fully_conn(neural_net, 100)
    neural_net = tf.nn.dropout(neural_net, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    neural_net = output(neural_net, num_outputs)
    
    
    # TODO: return output
    return neural_net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost,feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0})
    validation_accuracy = session.run(accuracy,feed_dict = {x: valid_features[:128], y: valid_labels[:128], keep_prob: 1.0})
    print("loss: ", loss)
    print("validation accuracy: ", validation_accuracy)
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 256
keep_probability = .75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss:  2.11479
# validation accuracy:  0.234375
# Epoch  2, CIFAR-10 Batch 1:  loss:  1.97977
# validation accuracy:  0.328125
# Epoch  3, CIFAR-10 Batch 1:  loss:  1.75792
# validation accuracy:  0.40625
# Epoch  4, CIFAR-10 Batch 1:  loss:  1.56684
# validation accuracy:  0.398438
# Epoch  5, CIFAR-10 Batch 1:  loss:  1.44065
# validation accuracy:  0.367188
# Epoch  6, CIFAR-10 Batch 1:  loss:  1.25502
# validation accuracy:  0.398438
# Epoch  7, CIFAR-10 Batch 1:  loss:  1.12845
# validation accuracy:  0.4375
# Epoch  8, CIFAR-10 Batch 1:  loss:  1.05925
# validation accuracy:  0.4375
# Epoch  9, CIFAR-10 Batch 1:  loss:  0.951528
# validation accuracy:  0.453125
# Epoch 10, CIFAR-10 Batch 1:  loss:  0.758609
# validation accuracy:  0.460938
# Epoch 11, CIFAR-10 Batch 1:  loss:  0.703101
# validation accuracy:  0.4375
# Epoch 12, CIFAR-10 Batch 1:  loss:  0.580436
# validation accuracy:  0.476562
# Epoch 13, CIFAR-10 Batch 1:  loss:  0.573205
# validation accuracy:  0.460938
# Epoch 14, CIFAR-10 Batch 1:  loss:  0.481766
# validation accuracy:  0.46875
# Epoch 15, CIFAR-10 Batch 1:  loss:  0.427721
# validation accuracy:  0.46875
# Epoch 16, CIFAR-10 Batch 1:  loss:  0.35597
# validation accuracy:  0.515625
# Epoch 17, CIFAR-10 Batch 1:  loss:  0.310553
# validation accuracy:  0.53125
# Epoch 18, CIFAR-10 Batch 1:  loss:  0.337121
# validation accuracy:  0.515625
# Epoch 19, CIFAR-10 Batch 1:  loss:  0.254662
# validation accuracy:  0.507812
# Epoch 20, CIFAR-10 Batch 1:  loss:  0.20036
# validation accuracy:  0.523438
# Epoch 21, CIFAR-10 Batch 1:  loss:  0.290522
# validation accuracy:  0.460938
# Epoch 22, CIFAR-10 Batch 1:  loss:  0.151002
# validation accuracy:  0.523438
# Epoch 23, CIFAR-10 Batch 1:  loss:  0.123296
# validation accuracy:  0.507812
# Epoch 24, CIFAR-10 Batch 1:  loss:  0.104803
# validation accuracy:  0.484375
# Epoch 25, CIFAR-10 Batch 1:  loss:  0.0877615
# validation accuracy:  0.453125
# Epoch 26, CIFAR-10 Batch 1:  loss:  0.0727696
# validation accuracy:  0.476562
# Epoch 27, CIFAR-10 Batch 1:  loss:  0.0527799
# validation accuracy:  0.445312
# Epoch 28, CIFAR-10 Batch 1:  loss:  0.0646453
# validation accuracy:  0.484375
# Epoch 29, CIFAR-10 Batch 1:  loss:  0.0661184
# validation accuracy:  0.429688
# Epoch 30, CIFAR-10 Batch 1:  loss:  0.0615158
# validation accuracy:  0.46875
# Epoch 31, CIFAR-10 Batch 1:  loss:  0.0434401
# validation accuracy:  0.476562
# Epoch 32, CIFAR-10 Batch 1:  loss:  0.0529525
# validation accuracy:  0.484375
# Epoch 33, CIFAR-10 Batch 1:  loss:  0.108609
# validation accuracy:  0.476562
# Epoch 34, CIFAR-10 Batch 1:  loss:  0.0457502
# validation accuracy:  0.554688
# Epoch 35, CIFAR-10 Batch 1:  loss:  0.0267585
# validation accuracy:  0.585938
# Epoch 36, CIFAR-10 Batch 1:  loss:  0.0210932
# validation accuracy:  0.578125
# Epoch 37, CIFAR-10 Batch 1:  loss:  0.00913868
# validation accuracy:  0.554688
# Epoch 38, CIFAR-10 Batch 1:  loss:  0.00693658
# validation accuracy:  0.601562
# Epoch 39, CIFAR-10 Batch 1:  loss:  0.00695721
# validation accuracy:  0.539062
# Epoch 40, CIFAR-10 Batch 1:  loss:  0.00761202
# validation accuracy:  0.539062
# Epoch 41, CIFAR-10 Batch 1:  loss:  0.00693407
# validation accuracy:  0.546875
# Epoch 42, CIFAR-10 Batch 1:  loss:  0.00562156
# validation accuracy:  0.515625
# Epoch 43, CIFAR-10 Batch 1:  loss:  0.0030182
# validation accuracy:  0.53125
# Epoch 44, CIFAR-10 Batch 1:  loss:  0.00472671
# validation accuracy:  0.5625
# Epoch 45, CIFAR-10 Batch 1:  loss:  0.00441696
# validation accuracy:  0.484375
# Epoch 46, CIFAR-10 Batch 1:  loss:  0.00279668
# validation accuracy:  0.539062
# Epoch 47, CIFAR-10 Batch 1:  loss:  0.00677172
# validation accuracy:  0.5625
# Epoch 48, CIFAR-10 Batch 1:  loss:  0.00332483
# validation accuracy:  0.492188
# Epoch 49, CIFAR-10 Batch 1:  loss:  0.00337545
# validation accuracy:  0.507812
# Epoch 50, CIFAR-10 Batch 1:  loss:  0.00159609
# validation accuracy:  0.523438

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss:  2.18624
# validation accuracy:  0.265625
# Epoch  1, CIFAR-10 Batch 2:  loss:  2.00701
# validation accuracy:  0.304688
# Epoch  1, CIFAR-10 Batch 3:  loss:  1.65341
# validation accuracy:  0.3125
# Epoch  1, CIFAR-10 Batch 4:  loss:  1.63716
# validation accuracy:  0.34375
# Epoch  1, CIFAR-10 Batch 5:  loss:  1.68302
# validation accuracy:  0.429688
# Epoch  2, CIFAR-10 Batch 1:  loss:  1.79362
# validation accuracy:  0.414062
# Epoch  2, CIFAR-10 Batch 2:  loss:  1.46303
# validation accuracy:  0.476562
# Epoch  2, CIFAR-10 Batch 3:  loss:  1.14737
# validation accuracy:  0.453125
# Epoch  2, CIFAR-10 Batch 4:  loss:  1.34951
# validation accuracy:  0.515625
# Epoch  2, CIFAR-10 Batch 5:  loss:  1.2843
# validation accuracy:  0.523438
# Epoch  3, CIFAR-10 Batch 1:  loss:  1.47638
# validation accuracy:  0.539062
# Epoch  3, CIFAR-10 Batch 2:  loss:  1.14968
# validation accuracy:  0.5
# Epoch  3, CIFAR-10 Batch 3:  loss:  0.799555
# validation accuracy:  0.554688
# Epoch  3, CIFAR-10 Batch 4:  loss:  1.00056
# validation accuracy:  0.523438
# Epoch  3, CIFAR-10 Batch 5:  loss:  1.01361
# validation accuracy:  0.546875
# Epoch  4, CIFAR-10 Batch 1:  loss:  1.06844
# validation accuracy:  0.554688
# Epoch  4, CIFAR-10 Batch 2:  loss:  0.902772
# validation accuracy:  0.578125
# Epoch  4, CIFAR-10 Batch 3:  loss:  0.619539
# validation accuracy:  0.570312
# Epoch  4, CIFAR-10 Batch 4:  loss:  0.841046
# validation accuracy:  0.601562
# Epoch  4, CIFAR-10 Batch 5:  loss:  0.854142
# validation accuracy:  0.539062
# Epoch  5, CIFAR-10 Batch 1:  loss:  0.88779
# validation accuracy:  0.585938
# Epoch  5, CIFAR-10 Batch 2:  loss:  0.725385
# validation accuracy:  0.609375
# Epoch  5, CIFAR-10 Batch 3:  loss:  0.425906
# validation accuracy:  0.632812
# Epoch  5, CIFAR-10 Batch 4:  loss:  0.679968
# validation accuracy:  0.601562
# Epoch  5, CIFAR-10 Batch 5:  loss:  0.668212
# validation accuracy:  0.5625
# Epoch  6, CIFAR-10 Batch 1:  loss:  0.743357
# validation accuracy:  0.617188
# Epoch  6, CIFAR-10 Batch 2:  loss:  0.632583
# validation accuracy:  0.640625
# Epoch  6, CIFAR-10 Batch 3:  loss:  0.38984
# validation accuracy:  0.671875
# Epoch  6, CIFAR-10 Batch 4:  loss:  0.45816
# validation accuracy:  0.648438
# Epoch  6, CIFAR-10 Batch 5:  loss:  0.503591
# validation accuracy:  0.664062
# Epoch  7, CIFAR-10 Batch 1:  loss:  0.657162
# validation accuracy:  0.625
# Epoch  7, CIFAR-10 Batch 2:  loss:  0.453373
# validation accuracy:  0.695312
# Epoch  7, CIFAR-10 Batch 3:  loss:  0.374844
# validation accuracy:  0.648438
# Epoch  7, CIFAR-10 Batch 4:  loss:  0.34644
# validation accuracy:  0.664062
# Epoch  7, CIFAR-10 Batch 5:  loss:  0.402019
# validation accuracy:  0.734375
# Epoch  8, CIFAR-10 Batch 1:  loss:  0.491409
# validation accuracy:  0.710938
# Epoch  8, CIFAR-10 Batch 2:  loss:  0.337622
# validation accuracy:  0.734375
# Epoch  8, CIFAR-10 Batch 3:  loss:  0.308484
# validation accuracy:  0.632812
# Epoch  8, CIFAR-10 Batch 4:  loss:  0.295278
# validation accuracy:  0.734375
# Epoch  8, CIFAR-10 Batch 5:  loss:  0.294133
# validation accuracy:  0.710938
# Epoch  9, CIFAR-10 Batch 1:  loss:  0.426641
# validation accuracy:  0.71875
# Epoch  9, CIFAR-10 Batch 2:  loss:  0.277241
# validation accuracy:  0.703125
# Epoch  9, CIFAR-10 Batch 3:  loss:  0.235104
# validation accuracy:  0.679688
# Epoch  9, CIFAR-10 Batch 4:  loss:  0.236564
# validation accuracy:  0.664062
# Epoch  9, CIFAR-10 Batch 5:  loss:  0.240229
# validation accuracy:  0.703125
# Epoch 10, CIFAR-10 Batch 1:  loss:  0.322972
# validation accuracy:  0.632812
# Epoch 10, CIFAR-10 Batch 2:  loss:  0.213742
# validation accuracy:  0.710938
# Epoch 10, CIFAR-10 Batch 3:  loss:  0.167226
# validation accuracy:  0.695312
# Epoch 10, CIFAR-10 Batch 4:  loss:  0.193024
# validation accuracy:  0.703125
# Epoch 10, CIFAR-10 Batch 5:  loss:  0.165246
# validation accuracy:  0.640625
# Epoch 11, CIFAR-10 Batch 1:  loss:  0.280933
# validation accuracy:  0.648438
# Epoch 11, CIFAR-10 Batch 2:  loss:  0.203978
# validation accuracy:  0.71875
# Epoch 11, CIFAR-10 Batch 3:  loss:  0.156043
# validation accuracy:  0.71875
# Epoch 11, CIFAR-10 Batch 4:  loss:  0.149114
# validation accuracy:  0.695312
# Epoch 11, CIFAR-10 Batch 5:  loss:  0.169515
# validation accuracy:  0.648438
# Epoch 12, CIFAR-10 Batch 1:  loss:  0.238449
# validation accuracy:  0.6875
# Epoch 12, CIFAR-10 Batch 2:  loss:  0.180121
# validation accuracy:  0.671875
# Epoch 12, CIFAR-10 Batch 3:  loss:  0.15146
# validation accuracy:  0.6875
# Epoch 12, CIFAR-10 Batch 4:  loss:  0.163787
# validation accuracy:  0.6875
# Epoch 12, CIFAR-10 Batch 5:  loss:  0.125942
# validation accuracy:  0.632812
# Epoch 13, CIFAR-10 Batch 1:  loss:  0.219315
# validation accuracy:  0.664062
# Epoch 13, CIFAR-10 Batch 2:  loss:  0.153392
# validation accuracy:  0.640625
# Epoch 13, CIFAR-10 Batch 3:  loss:  0.120391
# validation accuracy:  0.6875
# Epoch 13, CIFAR-10 Batch 4:  loss:  0.110179
# validation accuracy:  0.71875
# Epoch 13, CIFAR-10 Batch 5:  loss:  0.0960293
# validation accuracy:  0.632812
# Epoch 14, CIFAR-10 Batch 1:  loss:  0.141775
# validation accuracy:  0.695312
# Epoch 14, CIFAR-10 Batch 2:  loss:  0.111175
# validation accuracy:  0.710938
# Epoch 14, CIFAR-10 Batch 3:  loss:  0.110373
# validation accuracy:  0.671875
# Epoch 14, CIFAR-10 Batch 4:  loss:  0.0866831
# validation accuracy:  0.710938
# Epoch 14, CIFAR-10 Batch 5:  loss:  0.101345
# validation accuracy:  0.679688
# Epoch 15, CIFAR-10 Batch 1:  loss:  0.108462
# validation accuracy:  0.6875
# Epoch 15, CIFAR-10 Batch 2:  loss:  0.146248
# validation accuracy:  0.648438
# Epoch 15, CIFAR-10 Batch 3:  loss:  0.0916553
# validation accuracy:  0.695312
# Epoch 15, CIFAR-10 Batch 4:  loss:  0.0708048
# validation accuracy:  0.6875
# Epoch 15, CIFAR-10 Batch 5:  loss:  0.0639208
# validation accuracy:  0.671875
# Epoch 16, CIFAR-10 Batch 1:  loss:  0.107576
# validation accuracy:  0.6875
# Epoch 16, CIFAR-10 Batch 2:  loss:  0.0729612
# validation accuracy:  0.695312
# Epoch 16, CIFAR-10 Batch 3:  loss:  0.0446221
# validation accuracy:  0.679688
# Epoch 16, CIFAR-10 Batch 4:  loss:  0.0638686
# validation accuracy:  0.734375
# Epoch 16, CIFAR-10 Batch 5:  loss:  0.0845225
# validation accuracy:  0.671875
# Epoch 17, CIFAR-10 Batch 1:  loss:  0.0652446
# validation accuracy:  0.695312
# Epoch 17, CIFAR-10 Batch 2:  loss:  0.060343
# validation accuracy:  0.679688
# Epoch 17, CIFAR-10 Batch 3:  loss:  0.0444873
# validation accuracy:  0.632812
# Epoch 17, CIFAR-10 Batch 4:  loss:  0.0485879
# validation accuracy:  0.648438
# Epoch 17, CIFAR-10 Batch 5:  loss:  0.0272881
# validation accuracy:  0.71875
# Epoch 18, CIFAR-10 Batch 1:  loss:  0.049867
# validation accuracy:  0.671875
# Epoch 18, CIFAR-10 Batch 2:  loss:  0.0557478
# validation accuracy:  0.648438
# Epoch 18, CIFAR-10 Batch 3:  loss:  0.0369741
# validation accuracy:  0.640625
# Epoch 18, CIFAR-10 Batch 4:  loss:  0.0478577
# validation accuracy:  0.671875
# Epoch 18, CIFAR-10 Batch 5:  loss:  0.0472732
# validation accuracy:  0.71875
# Epoch 19, CIFAR-10 Batch 1:  loss:  0.04434
# validation accuracy:  0.648438
# Epoch 19, CIFAR-10 Batch 2:  loss:  0.0645169
# validation accuracy:  0.671875
# Epoch 19, CIFAR-10 Batch 3:  loss:  0.0260807
# validation accuracy:  0.679688
# Epoch 19, CIFAR-10 Batch 4:  loss:  0.0505695
# validation accuracy:  0.648438
# Epoch 19, CIFAR-10 Batch 5:  loss:  0.0360333
# validation accuracy:  0.703125
# Epoch 20, CIFAR-10 Batch 1:  loss:  0.0369969
# validation accuracy:  0.664062
# Epoch 20, CIFAR-10 Batch 2:  loss:  0.0617689
# validation accuracy:  0.648438
# Epoch 20, CIFAR-10 Batch 3:  loss:  0.0164987
# validation accuracy:  0.6875
# Epoch 20, CIFAR-10 Batch 4:  loss:  0.0434355
# validation accuracy:  0.640625
# Epoch 20, CIFAR-10 Batch 5:  loss:  0.0311619
# validation accuracy:  0.640625
# Epoch 21, CIFAR-10 Batch 1:  loss:  0.0518456
# validation accuracy:  0.648438
# Epoch 21, CIFAR-10 Batch 2:  loss:  0.0550322
# validation accuracy:  0.664062
# Epoch 21, CIFAR-10 Batch 3:  loss:  0.0299306
# validation accuracy:  0.703125
# Epoch 21, CIFAR-10 Batch 4:  loss:  0.0435209
# validation accuracy:  0.625
# Epoch 21, CIFAR-10 Batch 5:  loss:  0.0151487
# validation accuracy:  0.648438
# Epoch 22, CIFAR-10 Batch 1:  loss:  0.0247074
# validation accuracy:  0.625
# Epoch 22, CIFAR-10 Batch 2:  loss:  0.0523399
# validation accuracy:  0.671875
# Epoch 22, CIFAR-10 Batch 3:  loss:  0.011736
# validation accuracy:  0.679688
# Epoch 22, CIFAR-10 Batch 4:  loss:  0.0137773
# validation accuracy:  0.640625
# Epoch 22, CIFAR-10 Batch 5:  loss:  0.0192718
# validation accuracy:  0.679688
# Epoch 23, CIFAR-10 Batch 1:  loss:  0.0222774
# validation accuracy:  0.609375
# Epoch 23, CIFAR-10 Batch 2:  loss:  0.0279299
# validation accuracy:  0.632812
# Epoch 23, CIFAR-10 Batch 3:  loss:  0.0106498
# validation accuracy:  0.695312
# Epoch 23, CIFAR-10 Batch 4:  loss:  0.0190127
# validation accuracy:  0.625
# Epoch 23, CIFAR-10 Batch 5:  loss:  0.0160369
# validation accuracy:  0.625
# Epoch 24, CIFAR-10 Batch 1:  loss:  0.0181286
# validation accuracy:  0.65625
# Epoch 24, CIFAR-10 Batch 2:  loss:  0.0284427
# validation accuracy:  0.648438
# Epoch 24, CIFAR-10 Batch 3:  loss:  0.0118121
# validation accuracy:  0.671875
# Epoch 24, CIFAR-10 Batch 4:  loss:  0.0172028
# validation accuracy:  0.679688
# Epoch 24, CIFAR-10 Batch 5:  loss:  0.00877627
# validation accuracy:  0.679688
# Epoch 25, CIFAR-10 Batch 1:  loss:  0.010727
# validation accuracy:  0.664062
# Epoch 25, CIFAR-10 Batch 2:  loss:  0.0266896
# validation accuracy:  0.664062
# Epoch 25, CIFAR-10 Batch 3:  loss:  0.0133877
# validation accuracy:  0.695312
# Epoch 25, CIFAR-10 Batch 4:  loss:  0.017877
# validation accuracy:  0.695312
# Epoch 25, CIFAR-10 Batch 5:  loss:  0.00617631
# validation accuracy:  0.664062
# Epoch 26, CIFAR-10 Batch 1:  loss:  0.0174122
# validation accuracy:  0.664062
# Epoch 26, CIFAR-10 Batch 2:  loss:  0.0175255
# validation accuracy:  0.65625
# Epoch 26, CIFAR-10 Batch 3:  loss:  0.00719134
# validation accuracy:  0.664062
# Epoch 26, CIFAR-10 Batch 4:  loss:  0.0141066
# validation accuracy:  0.664062
# Epoch 26, CIFAR-10 Batch 5:  loss:  0.00765728
# validation accuracy:  0.640625
# Epoch 27, CIFAR-10 Batch 1:  loss:  0.0101342
# validation accuracy:  0.679688
# Epoch 27, CIFAR-10 Batch 2:  loss:  0.0163122
# validation accuracy:  0.648438
# Epoch 27, CIFAR-10 Batch 3:  loss:  0.0262229
# validation accuracy:  0.640625
# Epoch 27, CIFAR-10 Batch 4:  loss:  0.00792782
# validation accuracy:  0.640625
# Epoch 27, CIFAR-10 Batch 5:  loss:  0.00995085
# validation accuracy:  0.648438
# Epoch 28, CIFAR-10 Batch 1:  loss:  0.00564527
# validation accuracy:  0.664062
# Epoch 28, CIFAR-10 Batch 2:  loss:  0.0153243
# validation accuracy:  0.648438
# Epoch 28, CIFAR-10 Batch 3:  loss:  0.00790047
# validation accuracy:  0.617188
# Epoch 28, CIFAR-10 Batch 4:  loss:  0.00893649
# validation accuracy:  0.640625
# Epoch 28, CIFAR-10 Batch 5:  loss:  0.00350181
# validation accuracy:  0.679688
# Epoch 29, CIFAR-10 Batch 1:  loss:  0.00979805
# validation accuracy:  0.65625
# Epoch 29, CIFAR-10 Batch 2:  loss:  0.00966012
# validation accuracy:  0.6875
# Epoch 29, CIFAR-10 Batch 3:  loss:  0.00554084
# validation accuracy:  0.671875
# Epoch 29, CIFAR-10 Batch 4:  loss:  0.00761746
# validation accuracy:  0.679688
# Epoch 29, CIFAR-10 Batch 5:  loss:  0.00546097
# validation accuracy:  0.703125
# Epoch 30, CIFAR-10 Batch 1:  loss:  0.00473745
# validation accuracy:  0.65625
# Epoch 30, CIFAR-10 Batch 2:  loss:  0.0173576
# validation accuracy:  0.632812
# Epoch 30, CIFAR-10 Batch 3:  loss:  0.0109204
# validation accuracy:  0.65625
# Epoch 30, CIFAR-10 Batch 4:  loss:  0.00668305
# validation accuracy:  0.671875
# Epoch 30, CIFAR-10 Batch 5:  loss:  0.00760938
# validation accuracy:  0.65625
# Epoch 31, CIFAR-10 Batch 1:  loss:  0.00423239
# validation accuracy:  0.640625
# Epoch 31, CIFAR-10 Batch 2:  loss:  0.0147113
# validation accuracy:  0.648438
# Epoch 31, CIFAR-10 Batch 3:  loss:  0.00443555
# validation accuracy:  0.632812
# Epoch 31, CIFAR-10 Batch 4:  loss:  0.00974241
# validation accuracy:  0.695312
# Epoch 31, CIFAR-10 Batch 5:  loss:  0.0039555
# validation accuracy:  0.648438
# Epoch 32, CIFAR-10 Batch 1:  loss:  0.00433019
# validation accuracy:  0.671875
# Epoch 32, CIFAR-10 Batch 2:  loss:  0.00715441
# validation accuracy:  0.617188
# Epoch 32, CIFAR-10 Batch 3:  loss:  0.00463856
# validation accuracy:  0.648438
# Epoch 32, CIFAR-10 Batch 4:  loss:  0.00871972
# validation accuracy:  0.664062
# Epoch 32, CIFAR-10 Batch 5:  loss:  0.00255702
# validation accuracy:  0.65625
# Epoch 33, CIFAR-10 Batch 1:  loss:  0.00627493
# validation accuracy:  0.679688
# Epoch 33, CIFAR-10 Batch 2:  loss:  0.00705003
# validation accuracy:  0.65625
# Epoch 33, CIFAR-10 Batch 3:  loss:  0.00603919
# validation accuracy:  0.640625
# Epoch 33, CIFAR-10 Batch 4:  loss:  0.00419398
# validation accuracy:  0.679688
# Epoch 33, CIFAR-10 Batch 5:  loss:  0.00134798
# validation accuracy:  0.664062
# Epoch 34, CIFAR-10 Batch 1:  loss:  0.00857168
# validation accuracy:  0.6875
# Epoch 34, CIFAR-10 Batch 2:  loss:  0.011677
# validation accuracy:  0.65625
# Epoch 34, CIFAR-10 Batch 3:  loss:  0.00522509
# validation accuracy:  0.671875
# Epoch 34, CIFAR-10 Batch 4:  loss:  0.00514811
# validation accuracy:  0.664062
# Epoch 34, CIFAR-10 Batch 5:  loss:  0.00193952
# validation accuracy:  0.632812
# Epoch 35, CIFAR-10 Batch 1:  loss:  0.00344893
# validation accuracy:  0.65625
# Epoch 35, CIFAR-10 Batch 2:  loss:  0.00287839
# validation accuracy:  0.625
# Epoch 35, CIFAR-10 Batch 3:  loss:  0.00740564
# validation accuracy:  0.679688
# Epoch 35, CIFAR-10 Batch 4:  loss:  0.0127505
# validation accuracy:  0.695312
# Epoch 35, CIFAR-10 Batch 5:  loss:  0.00558617
# validation accuracy:  0.671875
# Epoch 36, CIFAR-10 Batch 1:  loss:  0.00950295
# validation accuracy:  0.671875
# Epoch 36, CIFAR-10 Batch 2:  loss:  0.00449251
# validation accuracy:  0.648438
# Epoch 36, CIFAR-10 Batch 3:  loss:  0.00944528
# validation accuracy:  0.648438
# Epoch 36, CIFAR-10 Batch 4:  loss:  0.00564118
# validation accuracy:  0.640625
# Epoch 36, CIFAR-10 Batch 5:  loss:  0.00245292
# validation accuracy:  0.640625
# Epoch 37, CIFAR-10 Batch 1:  loss:  0.00147024
# validation accuracy:  0.601562
# Epoch 37, CIFAR-10 Batch 2:  loss:  0.00128616
# validation accuracy:  0.648438
# Epoch 37, CIFAR-10 Batch 3:  loss:  0.00676799
# validation accuracy:  0.671875
# Epoch 37, CIFAR-10 Batch 4:  loss:  0.00212881
# validation accuracy:  0.609375
# Epoch 37, CIFAR-10 Batch 5:  loss:  0.0018491
# validation accuracy:  0.671875
# Epoch 38, CIFAR-10 Batch 1:  loss:  0.000752867
# validation accuracy:  0.632812
# Epoch 38, CIFAR-10 Batch 2:  loss:  0.00104247
# validation accuracy:  0.648438
# Epoch 38, CIFAR-10 Batch 3:  loss:  0.00476027
# validation accuracy:  0.648438
# Epoch 38, CIFAR-10 Batch 4:  loss:  0.00289694
# validation accuracy:  0.648438
# Epoch 38, CIFAR-10 Batch 5:  loss:  0.000963372
# validation accuracy:  0.648438
# Epoch 39, CIFAR-10 Batch 1:  loss:  0.00252362
# validation accuracy:  0.609375
# Epoch 39, CIFAR-10 Batch 2:  loss:  0.00203335
# validation accuracy:  0.695312
# Epoch 39, CIFAR-10 Batch 3:  loss:  0.000989199
# validation accuracy:  0.632812
# Epoch 39, CIFAR-10 Batch 4:  loss:  0.00268051
# validation accuracy:  0.617188
# Epoch 39, CIFAR-10 Batch 5:  loss:  0.000764909
# validation accuracy:  0.664062
# Epoch 40, CIFAR-10 Batch 1:  loss:  0.00178071
# validation accuracy:  0.632812
# Epoch 40, CIFAR-10 Batch 2:  loss:  0.00430636
# validation accuracy:  0.664062
# Epoch 40, CIFAR-10 Batch 3:  loss:  0.000887169
# validation accuracy:  0.632812
# Epoch 40, CIFAR-10 Batch 4:  loss:  0.00209376
# validation accuracy:  0.671875
# Epoch 40, CIFAR-10 Batch 5:  loss:  0.00186769
# validation accuracy:  0.601562
# Epoch 41, CIFAR-10 Batch 1:  loss:  0.00245713
# validation accuracy:  0.671875
# Epoch 41, CIFAR-10 Batch 2:  loss:  0.0015489
# validation accuracy:  0.632812
# Epoch 41, CIFAR-10 Batch 3:  loss:  0.000598221
# validation accuracy:  0.671875
# Epoch 41, CIFAR-10 Batch 4:  loss:  0.00169224
# validation accuracy:  0.640625
# Epoch 41, CIFAR-10 Batch 5:  loss:  0.000476053
# validation accuracy:  0.664062
# Epoch 42, CIFAR-10 Batch 1:  loss:  0.0017785
# validation accuracy:  0.632812
# Epoch 42, CIFAR-10 Batch 2:  loss:  0.000727563
# validation accuracy:  0.664062
# Epoch 42, CIFAR-10 Batch 3:  loss:  0.000883523
# validation accuracy:  0.664062
# Epoch 42, CIFAR-10 Batch 4:  loss:  0.00426412
# validation accuracy:  0.671875
# Epoch 42, CIFAR-10 Batch 5:  loss:  0.00130819
# validation accuracy:  0.703125
# Epoch 43, CIFAR-10 Batch 1:  loss:  0.0028896
# validation accuracy:  0.664062
# Epoch 43, CIFAR-10 Batch 2:  loss:  0.000893936
# validation accuracy:  0.664062
# Epoch 43, CIFAR-10 Batch 3:  loss:  0.000588858
# validation accuracy:  0.664062
# Epoch 43, CIFAR-10 Batch 4:  loss:  0.00219596
# validation accuracy:  0.648438
# Epoch 43, CIFAR-10 Batch 5:  loss:  0.00063536
# validation accuracy:  0.695312
# Epoch 44, CIFAR-10 Batch 1:  loss:  0.00107962
# validation accuracy:  0.625
# Epoch 44, CIFAR-10 Batch 2:  loss:  0.000489034
# validation accuracy:  0.601562
# Epoch 44, CIFAR-10 Batch 3:  loss:  0.000638907
# validation accuracy:  0.648438
# Epoch 44, CIFAR-10 Batch 4:  loss:  0.0026826
# validation accuracy:  0.679688
# Epoch 44, CIFAR-10 Batch 5:  loss:  0.00806803
# validation accuracy:  0.648438
# Epoch 45, CIFAR-10 Batch 1:  loss:  0.00135873
# validation accuracy:  0.609375
# Epoch 45, CIFAR-10 Batch 2:  loss:  0.00239659
# validation accuracy:  0.664062
# Epoch 45, CIFAR-10 Batch 3:  loss:  0.00113069
# validation accuracy:  0.703125
# Epoch 45, CIFAR-10 Batch 4:  loss:  0.00152651
# validation accuracy:  0.671875
# Epoch 45, CIFAR-10 Batch 5:  loss:  0.00208566
# validation accuracy:  0.664062
# Epoch 46, CIFAR-10 Batch 1:  loss:  0.000665009
# validation accuracy:  0.59375
# Epoch 46, CIFAR-10 Batch 2:  loss:  0.000828887
# validation accuracy:  0.625
# Epoch 46, CIFAR-10 Batch 3:  loss:  0.00647937
# validation accuracy:  0.671875
# Epoch 46, CIFAR-10 Batch 4:  loss:  0.00194576
# validation accuracy:  0.671875
# Epoch 46, CIFAR-10 Batch 5:  loss:  0.000213681
# validation accuracy:  0.726562
# Epoch 47, CIFAR-10 Batch 1:  loss:  0.000884981
# validation accuracy:  0.632812
# Epoch 47, CIFAR-10 Batch 2:  loss:  0.00100351
# validation accuracy:  0.648438
# Epoch 47, CIFAR-10 Batch 3:  loss:  0.000307199
# validation accuracy:  0.703125
# Epoch 47, CIFAR-10 Batch 4:  loss:  0.000679476
# validation accuracy:  0.648438
# Epoch 47, CIFAR-10 Batch 5:  loss:  0.000285137
# validation accuracy:  0.671875
# Epoch 48, CIFAR-10 Batch 1:  loss:  0.00133924
# validation accuracy:  0.617188
# Epoch 48, CIFAR-10 Batch 2:  loss:  0.00071689
# validation accuracy:  0.640625
# Epoch 48, CIFAR-10 Batch 3:  loss:  0.0022094
# validation accuracy:  0.617188
# Epoch 48, CIFAR-10 Batch 4:  loss:  0.000551881
# validation accuracy:  0.65625
# Epoch 48, CIFAR-10 Batch 5:  loss:  0.000937134
# validation accuracy:  0.679688
# Epoch 49, CIFAR-10 Batch 1:  loss:  0.000645076
# validation accuracy:  0.632812
# Epoch 49, CIFAR-10 Batch 2:  loss:  0.000836097
# validation accuracy:  0.617188
# Epoch 49, CIFAR-10 Batch 3:  loss:  0.000679954
# validation accuracy:  0.6875
# Epoch 49, CIFAR-10 Batch 4:  loss:  0.00181188
# validation accuracy:  0.6875
# Epoch 49, CIFAR-10 Batch 5:  loss:  0.000231257
# validation accuracy:  0.664062
# Epoch 50, CIFAR-10 Batch 1:  loss:  0.000609805
# validation accuracy:  0.648438
# Epoch 50, CIFAR-10 Batch 2:  loss:  0.000525052
# validation accuracy:  0.617188
# Epoch 50, CIFAR-10 Batch 3:  loss:  0.00031335
# validation accuracy:  0.679688
# Epoch 50, CIFAR-10 Batch 4:  loss:  0.000402181
# validation accuracy:  0.640625
# Epoch 50, CIFAR-10 Batch 5:  loss:  0.000390204
# validation accuracy:  0.640625

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)

test_model()
# Out:
# Testing Accuracy: 0.67119140625

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
